# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a series of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
movies.shape
#number of rows=979
#number of columns=6
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies.loc[:,'duration'].mean()
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.loc[:,['title','duration']].sort_values('duration',ascending=True)
# Out:
#                                              title  duration
# 389                                         Freaks        64
# 338                            Battleship Potemkin        66
# 258                    The Cabinet of Dr. Caligari        67
# 293                                      Duck Soup        68
# 88                                         The Kid        68
# 742                                      Following        69
# 351                                   Frankenstein        70
# 938                            Alice in Wonderland        75
# 405                      The Bride of Frankenstein        75
# 303                 The Nightmare Before Christmas        76
# 713                                The Jungle Book        78
# 864                                          [Rec]        78
# 489                     The Triplets of Belleville        78
# 535                                          Zelig        79
# ...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer:
ax=movies.loc[:,'duration'].plot(kind='hist',bins=10)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
ax=movies.loc[:,'duration'].plot(kind='box')

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer1:
movies.loc[:,['content_rating','title']].groupby('content_rating').count()
#Answer2:
movies.loc[:,'content_rating'].value_counts()
# Out:
# R            460
# PG-13        189
# PG           123
# NOT RATED     65
# APPROVED      47
# UNRATED       38
# G             32
# NC-17          7
# PASSED         7
# X              4
# GP             3
# TV-MA          1
# Name: content_rating, dtype: int64

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
movies.loc[:,['content_rating','title']].groupby('content_rating').count().plot(kind='bar')
plt.xlabel('Content Rating')
plt.ylabel('Movies Count')
# Out:
# Text(0,0.5,'Movies Count')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
# Answer:
#movies.content_rating.replace(['NOT RATED','APPROVED','PASSED','GP'],'UNRATED',inplace='True')
movies.content_rating.replace(['NOT RATED', 'APPROVED', 'PASSED', 'GP'], 'UNRATED')
# Out:
# 0            R
# 1            R
# 2            R
# 3        PG-13
# 4            R
# 5      UNRATED
# 6      UNRATED
# 7        PG-13
# 8            R
# 9            R
# 10       PG-13
# 11       PG-13
# 12          PG
# 13       PG-13
# 14       PG-13
# 15       PG-13
# 16           R
# 17     UNRATED
# 18           R
# 19          PG
# 20           R
# 21           R
# 22     UNRATED
# 23           R
# 24           R
# 25       PG-13
# 26       PG-13
# 27           R
# 28           R
# 29     UNRATED
#         ...
# 949         PG
# 950          R
# 951          R
# 952          R
# 953         PG
# 954      PG-13
# 955          R
# 956         PG
# 957          R
# 958      PG-13
# 959          R
# 960      PG-13
# 961          R
# 962         PG
# 963          R
# 964      PG-13
# 965      PG-13
# 966      PG-13
# 967          R
# 968          R
# 969          R
# 970          R
# 971          R
# 972      NC-17
# 973      PG-13
# 974         PG
# 975         PG
# 976      PG-13
# ...

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
movies.content_rating.replace(['X','TV-MA'],'NC-17')
# Out:
# 0              R
# 1              R
# 2              R
# 3          PG-13
# 4              R
# 5      NOT RATED
# 6      NOT RATED
# 7          PG-13
# 8              R
# 9              R
# 10         PG-13
# 11         PG-13
# 12            PG
# 13         PG-13
# 14         PG-13
# 15         PG-13
# 16             R
# 17       UNRATED
# 18             R
# 19            PG
# 20             R
# 21             R
# 22      APPROVED
# 23             R
# 24             R
# 25         PG-13
# 26         PG-13
# 27             R
# 28             R
# 29        PASSED
#          ...
# 949           PG
# 950            R
# 951            R
# 952            R
# 953           PG
# 954        PG-13
# 955            R
# 956           PG
# 957            R
# 958        PG-13
# 959            R
# 960        PG-13
# 961            R
# 962           PG
# 963            R
# 964        PG-13
# 965        PG-13
# 966        PG-13
# 967            R
# 968            R
# 969            R
# ...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
movies[movies.content_rating.isnull()]
movies.content_rating.fillna('UNRATED')
# Out:
# 0              R
# 1              R
# 2              R
# 3          PG-13
# 4              R
# 5      NOT RATED
# 6      NOT RATED
# 7          PG-13
# 8              R
# 9              R
# 10         PG-13
# 11         PG-13
# 12            PG
# 13         PG-13
# 14         PG-13
# 15         PG-13
# 16             R
# 17       UNRATED
# 18             R
# 19            PG
# 20             R
# 21             R
# 22      APPROVED
# 23             R
# 24             R
# 25         PG-13
# 26         PG-13
# 27             R
# 28             R
# 29        PASSED
#          ...
# 949           PG
# 950            R
# 951            R
# 952            R
# 953           PG
# 954        PG-13
# 955            R
# 956           PG
# 957            R
# 958        PG-13
# 959            R
# 960        PG-13
# 961            R
# 962           PG
# 963            R
# 964        PG-13
# 965        PG-13
# 966        PG-13
# 967            R
# 968            R
# 969            R
# ...

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
movies[movies.loc[:,'duration']>=120].star_rating.mean()
movies[movies.loc[:,'duration']<120].star_rating.mean()
# Out:
# 7.838666666666657

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
#movies.boxplot(column='duration', by='star_rating');
#movies.plot(kind='scatter', x='duration', y='star_rating')
movies.plot(kind='scatter', x='duration', y='star_rating',alpha=0.2)

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies.groupby('genre').duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:

movies.hist(column='duration', by='content_rating', sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b064198>,
# ...
#       dtype=object)

# %% [markdown]
# #### Determine the top rated movie (by star rating) for each genre.

# %%
# Answer:

movies.groupby('genre')['star_rating'].max()
# Out:
# genre
# Action       9.0
# Adventure    8.9
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.3
# Drama        8.9
# Family       7.9
# Fantasy      7.7
# Film-Noir    8.3
# History      8.0
# Horror       8.6
# Mystery      8.6
# Sci-Fi       8.2
# Thriller     8.0
# Western      8.9
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer:
movies[movies.title.isin(movies[movies.title.duplicated()].title)]
# Out:
#      star_rating                            title content_rating      genre  \
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 678          7.7                   Les Miserables          PG-13      Drama
# 703          7.6                          Dracula       APPROVED     Horror
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit            NaN  Adventure
#
#      duration                                        actors_list
# 466       158  [u'Daniel Craig', u'Rooney Mara', u'Christophe...
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...
# 662       110  [u'Jeff Bridges', u'Matt Damon', u'Hailee Stei...
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# **You only need to choose one of the options below.** However, solving for multiple options would count as "extra credit" that could e.g. raise your score from a 2 ("meets expectations") to a 3 ("exceeds expectations").

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:
movies.genre.value_counts()
genre_list = ['Action','Adventure','Animation','Biography','Comedy','Crime','Drama','Horror','Mystery']
movies[movies.genre.isin(genre_list)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:
genre_counts = movies.genre.value_counts()
genre_list = genre_counts[genre_counts >= 10].index
movies[movies.genre.isin(genre_list)].groupby('genre').star_rating.mean()
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:
movies.groupby('genre').star_rating.mean()[movies.genre.value_counts() >= 10]
# Out:
# genre
# Action       7.884559
# Adventure    7.933333
# Animation    7.914516
# Biography    7.862338
# Comedy       7.822436
# Crime        7.916935
# Drama        7.902518
# Horror       7.806897
# Mystery      7.975000
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:
genre_ratings = movies.groupby('genre').star_rating.agg(['count', 'mean'])
genre_ratings[genre_ratings['count'] >= 10]
# Out:
#            count      mean
# genre
# Action       136  7.884559
# Adventure     75  7.933333
# Animation     62  7.914516
# Biography     77  7.862338
# Comedy       156  7.822436
# Crime        124  7.916935
# Drama        278  7.902518
# Horror        29  7.806897
# Mystery       16  7.975000

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!

# %%
def repp(string):
    return string.replace("[","").replace("]","").replace("u'","").replace("',",",")[:-1]    
movies_list = movies['actors_list'].apply(repp)
actors_list = []
for movie_actors in movies_list:
    actors_list.append([e.strip() for e in movie_actors.split(',')])
actor_dict = {}
for actor in actors_list:
    for a in actor:
        if a in actor_dict:
            actor_dict[a] +=1
        else:
            actor_dict[a] = 1

actor_dict
# Out:
# {'Tim Robbins': 5,
#  'Morgan Freeman': 8,
#  'Bob Gunton': 1,
#  'Marlon Brando': 4,
#  'Al Pacino': 13,
#  'James Caan': 2,
#  'Robert De Niro': 18,
#  'Robert Duvall': 7,
#  'Christian Bale': 11,
#  'Heath Ledger': 2,
#  'Aaron Eckhart': 2,
#  'John Travolta': 1,
#  'Uma Thurman': 5,
#  'Samuel L. Jackson': 6,
#  'Henry Fonda': 3,
#  'Lee J. Cobb': 2,
#  'Martin Balsam': 1,
#  'Clint Eastwood': 14,
#  'Eli Wallach': 1,
#  'Lee Van Cleef': 2,
#  'Elijah Wood': 5,
#  'Viggo Mortensen': 4,
#  'Ian McKellen': 8,
#  'Liam Neeson': 5,
#  'Ralph Fiennes': 7,
#  'Ben Kingsley': 4,
#  'Brad Pitt': 14,
#  'Edward Norton': 7,
#  'Helena Bonham Carter': 4,
#  'Orlando Bloom': 2,
#  'Leonardo DiCaprio': 11,
#  'Joseph Gordon-Levitt': 6,
#  'Ellen Page': 2,
#  'Mark Hamill': 3,
#  'Harrison Ford': 10,
#  'Carrie Fisher': 4,
#  'Tom Hanks': 14,
#  'Robin Wright': 3,
#  'Gary Sinise': 2,
#  'Matthew McConaughey': 4,
#  'Anne Hathaway': 3,
#  'Jessica Chastain': 3,
#  'Jack Nicholson': 9,
# ...

# %%
movies.groupby('actors_list')['star_rating'].max()
# Out:
# actors_list
# [u"Brian O'Halloran", u'Jeff Anderson', u'Marilyn Ghigliotti']            7.9
# [u"Brian O'Halloran", u'Jeff Anderson', u'Rosario Dawson']                7.5
# [u"Paige O'Hara", u'Robby Benson', u'Richard White']                      8.1
# [u"Peter O'Toole", u'Alec Guinness', u'Anthony Quinn']                    8.4
# [u"Ryan O'Neal", u'Marisa Berenson', u'Patrick Magee']                    8.1
# [u'Aamir Khan', u'Gracy Singh', u'Rachel Shelley']                        8.3
# [u'Aamir Khan', u'Madhavan', u'Mona Singh']                               8.5
# [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Khanna']                      8.3
# [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']                           8.4
# [u'Aaron Eckhart', u'Cameron Bright', u'Maria Bello']                     7.6
# [u'Aaron Taylor-Johnson', u'Nicolas Cage', u'Chlo\xeb Grace Moretz']      7.7
# [u'Adam Sandler', u'Don Cheadle', u'Jada Pinkett Smith']                  7.5
# ...

# %%
movies.loc[:,'actors_list'].value_counts()
# Out:
# [u'Daniel Radcliffe', u'Emma Watson', u'Rupert Grint']                6
# [u'Mark Hamill', u'Harrison Ford', u'Carrie Fisher']                  3
# [u'Michael J. Fox', u'Christopher Lloyd', u'Lea Thompson']            2
# [u'Ian McKellen', u'Martin Freeman', u'Richard Armitage']             2
# [u'Tom Hanks', u'Tim Allen', u'Joan Cusack']                          2
# [u'Khalid Abdalla', u'Ahmad Khan Mahmoodzada', u'Atossa Leoni']       1
# [u'Don Cheadle', u'Sophie Okonedo', u'Joaquin Phoenix']               1
# [u'Jennifer Lawrence', u'Josh Hutcherson', u'Liam Hemsworth']         1
# [u'Jim Carrey', u'Danny DeVito', u'Gerry Becker']                     1
# [u'Albert Brooks', u'Ellen DeGeneres', u'Alexander Gould']            1
# [u'Spencer Tracy', u'Milton Berle', u'Ethel Merman']                  1
# [u'Emile Hirsch', u'Vince Vaughn', u'Catherine Keener']               1
# [u'Errol Flynn', u'Olivia de Havilland', u'Basil Rathbone']           1
# ...
